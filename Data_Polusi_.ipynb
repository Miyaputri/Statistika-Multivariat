# %% [markdown]
# <a href="https://colab.research.google.com/github/Miyaputri/Statistika-Multivariat/blob/main/Data_Polusi_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Random Generate Data

#Import Library
import numpy as np
import pandas as pd

np.random.seed(42)

# Matriks kovarian yang sama untuk semua kawasan (CO2, NO2, SO2, PM2.5)
cov_matrix = [[5, 1, 0.5, 1],
              [1, 4, 0.8, 0.6],
              [0.5, 0.8, 3, 0.4],
              [1, 0.6, 0.4, 6]]

# Mean untuk setiap kawasan
mean_industri = [10, 8, 5, 12]
mean_permukiman = [8, 6, 4, 10]
mean_hutan = [6, 4, 3, 7]

# Jumlah sampel per kawasan
n = 50

# Generate data multivariat normal
data_industri = np.random.multivariate_normal(mean_industri, cov_matrix, size=n)
data_permukiman = np.random.multivariate_normal(mean_permukiman, cov_matrix, size=n)
data_hutan = np.random.multivariate_normal(mean_hutan, cov_matrix, size=n)

# Gabungkan ke DataFrame
df = pd.DataFrame(
    np.vstack([data_industri, data_permukiman, data_hutan]),
    columns=['CO2', 'NO2', 'SO2', 'PM25']
)
df['kawasan'] = ['Industri'] * n + ['Permukiman'] * n + ['Hutan'] * n

# Lihat sebagian data
print(df.head())
# Out:
#          CO2        NO2       SO2       PM25   kawasan
# 0   9.954514   5.373383  6.286056  11.148864  Industri
# 1  11.972879   5.417220  4.884665  12.694457  Industri
# 2  10.767077   9.907032  5.201195  12.143964  Industri
# 3   5.276853   8.614247  4.573820  14.492883  Industri
# 4  10.713013  11.529852  4.426187  13.599463  Industri

# %%
from google.colab import files
df.to_csv('data_polusi.csv', index=False)
files.download('data_polusi.csv')

# %%
df
# Out:
#            CO2        NO2       SO2       PM25   kawasan
# 0     9.954514   5.373383  6.286056  11.148864  Industri
# 1    11.972879   5.417220  4.884665  12.694457  Industri
# 2    10.767077   9.907032  5.201195  12.143964  Industri
# 3     5.276853   8.614247  4.573820  14.492883  Industri
# 4    10.713013  11.529852  4.426187  13.599463  Industri
# ..         ...        ...       ...        ...       ...
# 145   5.877982   0.699739  5.301447   6.840413     Hutan
# 146   5.440684   5.301798  2.179815   6.333288     Hutan
# 147   3.811057   2.691455  1.454872   6.680047     Hutan
# 148   6.895944   2.940021  1.381440   5.540484     Hutan
# 149   4.716827   3.619612  3.585859   8.991359     Hutan
#
# [150 rows x 5 columns]
